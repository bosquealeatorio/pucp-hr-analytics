# %% [markdown]
# # HR Analytics
#
# <img src = 'https://datahack-prod.s3.ap-south-1.amazonaws.com/__sized__/contest_cover/hr_1920x480_s5WuoZs-thumbnail-1200x1200-90.jpg'>
#
# Practice Problem: https://datahack.analyticsvidhya.com/contest/wns-analytics-hackathon-2018-1/

# %% [markdown]
# ## HR Analytics
#
# HR analytics is revolutionising the way human resources departments operate, leading to higher efficiency and better results overall. Human resources has been using analytics for years. However, the collection, processing and analysis of data has been largely manual, and given the nature of human resources dynamics and HR KPIs, the approach has been constraining HR. Therefore, it is surprising that HR departments woke up to the utility of machine learning so late in the game. Here is an opportunity to try predictive analytics in identifying the employees most likely to get promoted.

# %% [markdown]
# ## Problem Statement
#
# Your client is a large MNC and they have 9 broad verticals across the organisation. One of the problem your client is facing is around identifying the right people for promotion *(only for manager position and below)* and prepare them in time. Currently the process, they are following is:
#
# * They first identify a set of employees based on recommendations/ past performance
# * Selected employees go through the separate training and evaluation program for each vertical. These programs are based on the required skill of each vertical
# * At the end of the program, based on various factors such as training performance, KPI completion (only employees with KPIs completed greater than 60% are considered) etc., employee gets promotion
#
# For above mentioned process, the final promotions are only announced after the evaluation and this leads to delay in transition to their new roles. Hence, company needs your help in identifying the eligible candidates at a particular checkpoint so that they can expedite the entire promotion cycle.

# %% [markdown]
# <img src = 'https://s3-ap-south-1.amazonaws.com/av-blog-media/wp-content/uploads/2018/09/wns_hack_im_1.jpg'>

# %% [markdown]
# They have provided multiple attributes around Employee's past and current performance along with demographics. Now, The task is to predict whether a potential promotee at checkpoint in the test set will be promoted or not after the evaluation process.

# %% [markdown]
# ## Evaluation Metric
#
# The evaluation metric for this competition is F1 Score.
#
# ## Public and Private Split
#
# Test data is further randomly divided into Public (40%) and Private (60%) data.
#
# Your initial responses will be checked and scored on the Public data.
# The final rankings would be based on your private score which will be published once the competition is over.

# %% [markdown]
# ## Entorno

# %%
import sys
sys.version
# Out:
# '3.7.9 (default, Aug 31 2020, 17:10:11) [MSC v.1916 64 bit (AMD64)]'

# %%
# !conda info --envs
# Out:
# # conda environments:
# #
# micromaster              /Users/manuel/.conda/envs/micromaster
#                          /Users/manuel/.julia/conda/3
# base                  *  /Users/manuel/opt/anaconda3
# belcorp                  /Users/manuel/opt/anaconda3/envs/belcorp
# courseragcp              /Users/manuel/opt/anaconda3/envs/courseragcp
# iapucp                   /Users/manuel/opt/anaconda3/envs/iapucp
# mitxpro                  /Users/manuel/opt/anaconda3/envs/mitxpro
# style-transfer           /Users/manuel/opt/anaconda3/envs/style-transfer
# taller-dmc               /Users/manuel/opt/anaconda3/envs/taller-dmc
# udacity                  /Users/manuel/opt/anaconda3/envs/udacity

# %% [markdown]
# ## Paquetes

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import os
import numpy as np
import pandas as pd
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm, tqdm_notebook
from pathlib import Path
import random
import warnings
import pickle

warnings.filterwarnings('ignore')


seed = 2020
random.seed(seed)

pd.set_option('display.max_columns', 1000)
pd.set_option('display.max_rows', 400)
sns.set()

DATA = Path('../../data') 
RAW  = DATA/'raw'
PROCESSED = DATA/'processed'
SUBMISSIONS = DATA/'submissions'    

MODEL = Path('../../model')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
pd.__version__
# Out:
# '1.1.3'

# %%
np.__version__
# Out:
# '1.19.2'

# %%
sklearn.__version__
# Out:
# '0.23.2'

# %%
id_columns = 'employee_id'
target = 'is_promoted'

# %% [markdown]
# ## Lectura de datos

# %%
os.listdir(f'{PROCESSED}')
# Out:
# ['.DS_Store',
#  'preprocess_v1_capping_values.pkl',
#  'preprocess_v1_impute_values.pkl',
#  'preprocess_v1_ohe.pkl',
#  'preprocess_v1_ohe_columns.pkl',
#  'preprocess_v1_over50_train.csv',
#  'preprocess_v1_scaler.pkl',
#  'preprocess_v1_smote20_train.csv',
#  'preprocess_v1_smote50_train.csv',
#  'preprocess_v1_smoteTomek20_train.csv',
#  'preprocess_v1_smoteTomek50_train.csv',
#  'preprocess_v1_train.csv',
#  'preprocess_v1_under50_train.csv',
#  'preprocess_v1_val.csv',
#  'preprocess_v2_capping_values.pkl',
#  'preprocess_v2_knnimputation.pkl',
#  'preprocess_v2_ohe.pkl',
#  'preprocess_v2_ohe_columns.pkl',
#  'preprocess_v2_over50_train.csv',
#  'preprocess_v2_scaler.pkl',
#  'preprocess_v2_scalerimputation.pkl',
#  'preprocess_v2_smote20_train.csv',
#  'preprocess_v2_smote50_train.csv',
#  'preprocess_v2_smoteTomek20_train.csv',
#  'preprocess_v2_smoteTomek50_train.csv',
#  'preprocess_v2_test.csv',
#  'preprocess_v2_train.csv',
#  'preprocess_v2_under50_train.csv',
#  'preprocess_v2_val.csv']

# %% [markdown]
# ## Entrenamiento V1 sin balanceo

# %%
from sklearn.linear_model import LogisticRegression 
from sklearn.metrics import precision_recall_curve, roc_auc_score, f1_score

# %%
preproc_train = [file for file in os.listdir(f'{PROCESSED}') if file.endswith('train.csv')]
preproc_train
# Out:
# ['preprocess_v1_over50_train.csv',
#  'preprocess_v1_smote20_train.csv',
#  'preprocess_v1_smote50_train.csv',
#  'preprocess_v1_smoteTomek20_train.csv',
#  'preprocess_v1_smoteTomek50_train.csv',
#  'preprocess_v1_train.csv',
#  'preprocess_v1_under50_train.csv',
#  'preprocess_v2_over50_train.csv',
#  'preprocess_v2_smote20_train.csv',
#  'preprocess_v2_smote50_train.csv',
#  'preprocess_v2_smoteTomek20_train.csv',
#  'preprocess_v2_smoteTomek50_train.csv',
#  'preprocess_v2_train.csv',
#  'preprocess_v2_under50_train.csv']

# %%
preproc_val = [file for file in os.listdir(f'{PROCESSED}') if file.endswith('val.csv')]
preproc_val
# Out:
# ['preprocess_v1_val.csv', 'preprocess_v2_val.csv']

# %%
for train_file in sorted(preproc_train):
    df_train = pd.read_csv(f'{PROCESSED}/{train_file}', compression = 'zip')
    df_val = pd.read_csv(f'{PROCESSED}/{preproc_val[0]}', compression = 'zip')
    
    print(f'label: {train_file:35} \tnrows: {len(df_train)} \t%target train: {df_train[target].mean():.4f} \t%target val: {df_val[target].mean():.4f}')
# Out:
# label: preprocess_v1_over50_train.csv      	nrows: 80224 	%target train: 0.5000 	%target val: 0.0852
# label: preprocess_v1_smote20_train.csv     	nrows: 48134 	%target train: 0.1667 	%target val: 0.0852
# label: preprocess_v1_smote50_train.csv     	nrows: 80224 	%target train: 0.5000 	%target val: 0.0852
# label: preprocess_v1_smoteTomek20_train.csv 	nrows: 46412 	%target train: 0.1543 	%target val: 0.0852
# label: preprocess_v1_smoteTomek50_train.csv 	nrows: 79638 	%target train: 0.5000 	%target val: 0.0852
# label: preprocess_v1_train.csv             	nrows: 43846 	%target train: 0.0852 	%target val: 0.0852
# label: preprocess_v1_under50_train.csv     	nrows: 7468 	%target train: 0.5000 	%target val: 0.0852
# label: preprocess_v2_over50_train.csv      	nrows: 80224 	%target train: 0.5000 	%target val: 0.0852
# label: preprocess_v2_smote20_train.csv     	nrows: 48134 	%target train: 0.1667 	%target val: 0.0852
# label: preprocess_v2_smote50_train.csv     	nrows: 80224 	%target train: 0.5000 	%target val: 0.0852
# label: preprocess_v2_smoteTomek20_train.csv 	nrows: 46390 	%target train: 0.1541 	%target val: 0.0852
# label: preprocess_v2_smoteTomek50_train.csv 	nrows: 79638 	%target train: 0.5000 	%target val: 0.0852
# label: preprocess_v2_train.csv             	nrows: 43846 	%target train: 0.0852 	%target val: 0.0852
# label: preprocess_v2_under50_train.csv     	nrows: 7468 	%target train: 0.5000 	%target val: 0.0852

# %%
train_file = 'preprocess_v1_train.csv'
val_file = 'preprocess_v1_val.csv'

# %%
from sklearn.model_selection import ParameterGrid

# %%
cv_grid = {'penalty': ['l1','l2'],'solver': ['liblinear','saga'],
              'C': [0.001,0.01,0.1,1,10,100,1000],
            'random_state': [seed]}

params_grid = list(ParameterGrid(cv_grid))

# %%
df_results = pd.DataFrame(columns = ['preproc_label', 'model_label', 'método', 'parámetros', 'columnas_out',
                                     'auc_train', 'auc_val', 'threshold','f1_train', 'f1_val'])


for xgb_params in tqdm(params_grid):
    
    for train_file in sorted(preproc_train):

        preproc_label = train_file.split('_train')[0]

        print('----------------------------------------------------------------------')
        print(xgb_params)
        print(train_file)
        print('----------------------------------------------------------------------')

        df_train = pd.read_csv(f'{PROCESSED}/{train_file}', compression = 'zip')
        df_val = pd.read_csv(f'{PROCESSED}/{preproc_val[0]}', compression = 'zip')

        X_train, y_train = df_train.drop(target, axis = 1), df_train[target]
        X_val, y_val = df_val.drop(target, axis = 1), df_val[target]

        logi = LogisticRegression(solver = xgb_params["solver"],penalty =xgb_params["penalty"], C =xgb_params["C"], random_state= xgb_params["random_state"])
        logi_fit = logi.fit( X_train,y_train )
                        
        
        #xgb_params_export = xgb_params.copy()
        #xgb_params_export.update(logi_fit.attributes())

        probs_train = logi_fit.predict(X_train)
        probs_val = logi_fit.predict(X_val)

        auc_train = roc_auc_score(y_train, probs_train)
        auc_val = roc_auc_score(y_val, probs_val)

        #best threshold
        prec, recall, threshold = precision_recall_curve(y_train, probs_train)
        prec_recall = pd.DataFrame({'prec': prec[:-1], 'recall': recall[:-1], 'threshold': threshold})
        prec_recall['f1'] = 2*prec_recall['prec']*prec_recall['recall'] / (prec_recall['prec'] + prec_recall['recall'])
        prec_recall = prec_recall.sort_values(by = 'f1', ascending = False).head(1)

        #f1 scores
        best_threshold = prec_recall['threshold'].values[0]
        f1_train = prec_recall['f1'].values[0]

        labels_val = np.where(probs_val >= best_threshold, 1, 0)
        f1_val = f1_score(y_val, labels_val)

        print(f'auc_train: {auc_train:.6f} \tauc_val: {auc_val:.6f} \tf1_train: {f1_train:.6f} \tf1_val: {f1_val:.6f}')

        results = [preproc_label, 'LogisticRegression', 'fit', xgb_params, '',
                  auc_train, auc_val, best_threshold, f1_train, f1_val]


        df_results.loc[len(df_results)] = results
# Out:
#   0%|          | 0/28 [00:00<?, ?it/s]
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_over50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.772961 	auc_val: 0.779456 	f1_train: 0.784061 	f1_val: 0.346537
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_smote20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.543655 	auc_val: 0.551785 	f1_train: 0.285704 	f1_val: 0.157028
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_smote50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.788791 	auc_val: 0.781288 	f1_train: 0.802107 	f1_val: 0.348910
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_smoteTomek20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.540606 	auc_val: 0.548873 	f1_train: 0.267336 	f1_val: 0.157028
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_smoteTomek50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.792838 	auc_val: 0.782408 	f1_train: 0.805856 	f1_val: 0.349722
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.500000 	auc_val: 0.500000 	f1_train: 0.156957 	f1_val: 0.157028
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_under50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.713846 	auc_val: 0.712636 	f1_train: 0.723866 	f1_val: 0.286592
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_over50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.772662 	auc_val: 0.779656 	f1_train: 0.783843 	f1_val: 0.346844
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_smote20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.543643 	auc_val: 0.551785 	f1_train: 0.285704 	f1_val: 0.157028
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_smote50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.788617 	auc_val: 0.781450 	f1_train: 0.801916 	f1_val: 0.349632
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_smoteTomek20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.540088 	auc_val: 0.548337 	f1_train: 0.267090 	f1_val: 0.157028
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_smoteTomek50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.792850 	auc_val: 0.781836 	f1_train: 0.805915 	f1_val: 0.349766
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.500000 	auc_val: 0.500000 	f1_train: 0.156957 	f1_val: 0.157028
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_under50_train.csv
# ----------------------------------------------------------------------
#   4%|▎         | 1/28 [00:18<08:23, 18.66s/it]
# auc_train: 0.713846 	auc_val: 0.712636 	f1_train: 0.723866 	f1_val: 0.286592
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_over50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.766117 	auc_val: 0.777858 	f1_train: 0.773844 	f1_val: 0.351086
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_smote20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.540414 	auc_val: 0.548337 	f1_train: 0.285704 	f1_val: 0.157028
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_smote50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.782235 	auc_val: 0.772940 	f1_train: 0.792749 	f1_val: 0.347527
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_smoteTomek20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.537212 	auc_val: 0.542847 	f1_train: 0.267336 	f1_val: 0.157028
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_smoteTomek50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.786245 	auc_val: 0.772156 	f1_train: 0.796500 	f1_val: 0.346752
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.500937 	auc_val: 0.501606 	f1_train: 0.156957 	f1_val: 0.157028
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_under50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.713444 	auc_val: 0.711941 	f1_train: 0.722726 	f1_val: 0.286892
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_over50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.765868 	auc_val: 0.777223 	f1_train: 0.773811 	f1_val: 0.350548
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_smote20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.540938 	auc_val: 0.547852 	f1_train: 0.285704 	f1_val: 0.157028
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_smote50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.782123 	auc_val: 0.774124 	f1_train: 0.792694 	f1_val: 0.348944
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_smoteTomek20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.537610 	auc_val: 0.543968 	f1_train: 0.267090 	f1_val: 0.157028
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_smoteTomek50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.786032 	auc_val: 0.772954 	f1_train: 0.796357 	f1_val: 0.348026
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.501071 	auc_val: 0.501606 	f1_train: 0.156957 	f1_val: 0.157028
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_under50_train.csv
# ----------------------------------------------------------------------
#   7%|▋         | 2/28 [00:40<08:33, 19.74s/it]
# auc_train: 0.713444 	auc_val: 0.711941 	f1_train: 0.722726 	f1_val: 0.286892
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_over50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.782297 	auc_val: 0.785752 	f1_train: 0.792264 	f1_val: 0.356996
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_smote20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.591449 	auc_val: 0.606785 	f1_train: 0.310626 	f1_val: 0.334129
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_smote50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.796470 	auc_val: 0.783812 	f1_train: 0.807919 	f1_val: 0.357836
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_smoteTomek20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.594898 	auc_val: 0.604571 	f1_train: 0.318511 	f1_val: 0.331438
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_smoteTomek50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.799995 	auc_val: 0.785618 	f1_train: 0.811284 	f1_val: 0.359306
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.546732 	auc_val: 0.557204 	f1_train: 0.170936 	f1_val: 0.204503
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_under50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.758302 	auc_val: 0.757935 	f1_train: 0.774234 	f1_val: 0.319505
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_over50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.782085 	auc_val: 0.786187 	f1_train: 0.792212 	f1_val: 0.357208
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_smote20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.591199 	auc_val: 0.606885 	f1_train: 0.309926 	f1_val: 0.334661
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_smote50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.796545 	auc_val: 0.783676 	f1_train: 0.808071 	f1_val: 0.358119
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_smoteTomek20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.594503 	auc_val: 0.604035 	f1_train: 0.317435 	f1_val: 0.330081
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_smoteTomek50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.799932 	auc_val: 0.785295 	f1_train: 0.811352 	f1_val: 0.359796
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.546866 	auc_val: 0.557304 	f1_train: 0.171374 	f1_val: 0.204887
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_under50_train.csv
# ----------------------------------------------------------------------
#  11%|█         | 3/28 [00:58<07:59, 19.19s/it]
# auc_train: 0.759373 	auc_val: 0.759604 	f1_train: 0.775066 	f1_val: 0.320993
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_over50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.777747 	auc_val: 0.780852 	f1_train: 0.785382 	f1_val: 0.358013
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_smote20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.584007 	auc_val: 0.600774 	f1_train: 0.289973 	f1_val: 0.321633
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_smote50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.792182 	auc_val: 0.782511 	f1_train: 0.801604 	f1_val: 0.361354
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_smoteTomek20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.586706 	auc_val: 0.595247 	f1_train: 0.296128 	f1_val: 0.309623
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_smoteTomek50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.794457 	auc_val: 0.782311 	f1_train: 0.803632 	f1_val: 0.361013
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.537645 	auc_val: 0.542029 	f1_train: 0.156957 	f1_val: 0.157028
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_under50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.743037 	auc_val: 0.740841 	f1_train: 0.745794 	f1_val: 0.322065
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_over50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.776002 	auc_val: 0.781039 	f1_train: 0.783478 	f1_val: 0.357811
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_smote20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.583895 	auc_val: 0.600823 	f1_train: 0.289655 	f1_val: 0.321895
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_smote50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.792107 	auc_val: 0.781068 	f1_train: 0.801632 	f1_val: 0.360999
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_smoteTomek20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.586813 	auc_val: 0.595197 	f1_train: 0.296406 	f1_val: 0.309365
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_smoteTomek50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.794809 	auc_val: 0.782474 	f1_train: 0.804100 	f1_val: 0.361823
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.537487 	auc_val: 0.541543 	f1_train: 0.156957 	f1_val: 0.157028
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_under50_train.csv
# ----------------------------------------------------------------------
#  14%|█▍        | 4/28 [01:18<07:45, 19.40s/it]
# auc_train: 0.744376 	auc_val: 0.742274 	f1_train: 0.746985 	f1_val: 0.323779
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_over50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.791534 	auc_val: 0.797508 	f1_train: 0.798690 	f1_val: 0.379075
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_smote20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.644304 	auc_val: 0.655805 	f1_train: 0.436617 	f1_val: 0.424201
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_smote50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.807489 	auc_val: 0.798511 	f1_train: 0.815466 	f1_val: 0.385886
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_smoteTomek20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.656866 	auc_val: 0.656815 	f1_train: 0.463199 	f1_val: 0.432245
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_smoteTomek50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.809526 	auc_val: 0.797204 	f1_train: 0.817093 	f1_val: 0.385252
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.585839 	auc_val: 0.594541 	f1_train: 0.291114 	f1_val: 0.315883
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_under50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.769952 	auc_val: 0.779456 	f1_train: 0.781703 	f1_val: 0.346537
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_over50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.790487 	auc_val: 0.797994 	f1_train: 0.797616 	f1_val: 0.379377
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_smote20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.642995 	auc_val: 0.655955 	f1_train: 0.433750 	f1_val: 0.425068
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_smote50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.807402 	auc_val: 0.798760 	f1_train: 0.815438 	f1_val: 0.386369
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_smoteTomek20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.656509 	auc_val: 0.656915 	f1_train: 0.462513 	f1_val: 0.432846
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_smoteTomek50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.810191 	auc_val: 0.796818 	f1_train: 0.817897 	f1_val: 0.385137
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.585839 	auc_val: 0.594006 	f1_train: 0.291114 	f1_val: 0.314387
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_under50_train.csv
# ----------------------------------------------------------------------
#  18%|█▊        | 5/28 [02:11<11:17, 29.46s/it]
# auc_train: 0.769282 	auc_val: 0.777467 	f1_train: 0.780649 	f1_val: 0.347144
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_over50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.791434 	auc_val: 0.797235 	f1_train: 0.798380 	f1_val: 0.379765
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_smote20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.644030 	auc_val: 0.655120 	f1_train: 0.436050 	f1_val: 0.422267
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_smote50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.806941 	auc_val: 0.798474 	f1_train: 0.814666 	f1_val: 0.386449
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_smoteTomek20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.655850 	auc_val: 0.656815 	f1_train: 0.460969 	f1_val: 0.432245
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_smoteTomek50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.809061 	auc_val: 0.797802 	f1_train: 0.816366 	f1_val: 0.386415
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.585910 	auc_val: 0.594491 	f1_train: 0.291171 	f1_val: 0.315603
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_under50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.759909 	auc_val: 0.771075 	f1_train: 0.766992 	f1_val: 0.347405
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_over50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.790387 	auc_val: 0.797322 	f1_train: 0.797275 	f1_val: 0.379327
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_smote20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.642633 	auc_val: 0.655419 	f1_train: 0.432966 	f1_val: 0.423995
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_smote50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.807053 	auc_val: 0.799109 	f1_train: 0.814838 	f1_val: 0.387048
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_smoteTomek20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.655949 	auc_val: 0.655894 	f1_train: 0.461313 	f1_val: 0.430962
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_smoteTomek50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.809664 	auc_val: 0.796682 	f1_train: 0.817109 	f1_val: 0.385506
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.585801 	auc_val: 0.594541 	f1_train: 0.290917 	f1_val: 0.315883
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_under50_train.csv
# ----------------------------------------------------------------------
#  21%|██▏       | 6/28 [02:57<12:34, 34.29s/it]
# auc_train: 0.760846 	auc_val: 0.770775 	f1_train: 0.768172 	f1_val: 0.346925
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_over50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.792032 	auc_val: 0.797122 	f1_train: 0.799259 	f1_val: 0.378958
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_smote20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.639529 	auc_val: 0.648024 	f1_train: 0.426371 	f1_val: 0.409373
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_smote50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.807128 	auc_val: 0.800054 	f1_train: 0.815431 	f1_val: 0.386341
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_smoteTomek20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.646546 	auc_val: 0.643744 	f1_train: 0.441491 	f1_val: 0.408309
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_smoteTomek50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.810003 	auc_val: 0.798261 	f1_train: 0.817846 	f1_val: 0.385404
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.583195 	auc_val: 0.591665 	f1_train: 0.283266 	f1_val: 0.307282
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_under50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.784681 	auc_val: 0.784072 	f1_train: 0.794216 	f1_val: 0.356749
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_over50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.791422 	auc_val: 0.796487 	f1_train: 0.798667 	f1_val: 0.378378
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_smote20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.638532 	auc_val: 0.645211 	f1_train: 0.424104 	f1_val: 0.405010
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_smote50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.807103 	auc_val: 0.799681 	f1_train: 0.815508 	f1_val: 0.386887
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_smoteTomek20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.646198 	auc_val: 0.642537 	f1_train: 0.440648 	f1_val: 0.407220
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_smoteTomek50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.810179 	auc_val: 0.798175 	f1_train: 0.818137 	f1_val: 0.385868
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.583462 	auc_val: 0.591715 	f1_train: 0.284040 	f1_val: 0.307556
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_under50_train.csv
# ----------------------------------------------------------------------
#  25%|██▌       | 7/28 [03:18<10:35, 30.24s/it]
# auc_train: 0.783878 	auc_val: 0.783414 	f1_train: 0.793183 	f1_val: 0.357176
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_over50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.791845 	auc_val: 0.796936 	f1_train: 0.798858 	f1_val: 0.379209
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_smote20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.637485 	auc_val: 0.647003 	f1_train: 0.421871 	f1_val: 0.407459
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_smote50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.806417 	auc_val: 0.799482 	f1_train: 0.814483 	f1_val: 0.386500
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_smoteTomek20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.644439 	auc_val: 0.640532 	f1_train: 0.436798 	f1_val: 0.401439
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_smoteTomek50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.809312 	auc_val: 0.798275 	f1_train: 0.816904 	f1_val: 0.386062
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.581915 	auc_val: 0.589474 	f1_train: 0.279395 	f1_val: 0.300980
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_under50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.778254 	auc_val: 0.780915 	f1_train: 0.785603 	f1_val: 0.358637
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_over50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.791883 	auc_val: 0.796251 	f1_train: 0.799003 	f1_val: 0.378537
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_smote20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.637049 	auc_val: 0.644576 	f1_train: 0.420848 	f1_val: 0.403338
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_smote50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.806828 	auc_val: 0.799831 	f1_train: 0.814972 	f1_val: 0.387178
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_smoteTomek20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.644965 	auc_val: 0.639861 	f1_train: 0.437942 	f1_val: 0.401449
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_smoteTomek50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.809563 	auc_val: 0.798138 	f1_train: 0.817229 	f1_val: 0.386432
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.582475 	auc_val: 0.590009 	f1_train: 0.281074 	f1_val: 0.302491
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_under50_train.csv
# ----------------------------------------------------------------------
#  29%|██▊       | 8/28 [03:41<09:24, 28.21s/it]
# auc_train: 0.778388 	auc_val: 0.780120 	f1_train: 0.785594 	f1_val: 0.359375
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_over50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.791571 	auc_val: 0.794748 	f1_train: 0.797887 	f1_val: 0.379941
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_smote20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.670283 	auc_val: 0.682304 	f1_train: 0.485654 	f1_val: 0.454657
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_smote50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.806679 	auc_val: 0.796149 	f1_train: 0.813618 	f1_val: 0.387672
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_smoteTomek20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.686690 	auc_val: 0.683327 	f1_train: 0.516692 	f1_val: 0.464736
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_smoteTomek50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.808935 	auc_val: 0.794829 	f1_train: 0.815550 	f1_val: 0.386358
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.624458 	auc_val: 0.635536 	f1_train: 0.387901 	f1_val: 0.417208
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_under50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.791778 	auc_val: 0.799266 	f1_train: 0.799070 	f1_val: 0.382968
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_over50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.791197 	auc_val: 0.795619 	f1_train: 0.797500 	f1_val: 0.380365
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_smote20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.670357 	auc_val: 0.682018 	f1_train: 0.485668 	f1_val: 0.455105
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_smote50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.806866 	auc_val: 0.796299 	f1_train: 0.813841 	f1_val: 0.387968
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_smoteTomek20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.686531 	auc_val: 0.682020 	f1_train: 0.516606 	f1_val: 0.463585
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_smoteTomek50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.809425 	auc_val: 0.795328 	f1_train: 0.816101 	f1_val: 0.387344
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.624215 	auc_val: 0.635200 	f1_train: 0.387400 	f1_val: 0.417278
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_under50_train.csv
# ----------------------------------------------------------------------
#  32%|███▏      | 9/28 [06:13<20:39, 65.24s/it]
# auc_train: 0.791377 	auc_val: 0.798445 	f1_train: 0.798864 	f1_val: 0.382643
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_over50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.791521 	auc_val: 0.794797 	f1_train: 0.797805 	f1_val: 0.380035
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_smote20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.670470 	auc_val: 0.682304 	f1_train: 0.486022 	f1_val: 0.454657
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_smote50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.806691 	auc_val: 0.796199 	f1_train: 0.813615 	f1_val: 0.387771
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_smoteTomek20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.686329 	auc_val: 0.683427 	f1_train: 0.515978 	f1_val: 0.465322
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_smoteTomek50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.808822 	auc_val: 0.794929 	f1_train: 0.815399 	f1_val: 0.386555
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.624190 	auc_val: 0.636071 	f1_train: 0.387242 	f1_val: 0.418491
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_under50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.791644 	auc_val: 0.799479 	f1_train: 0.798654 	f1_val: 0.383988
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_over50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.791160 	auc_val: 0.795233 	f1_train: 0.797432 	f1_val: 0.380247
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_smote20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.670233 	auc_val: 0.682068 	f1_train: 0.485423 	f1_val: 0.455385
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_smote50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.806791 	auc_val: 0.796299 	f1_train: 0.813724 	f1_val: 0.387968
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_smoteTomek20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.686461 	auc_val: 0.681971 	f1_train: 0.516473 	f1_val: 0.463291
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_smoteTomek50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.809387 	auc_val: 0.794892 	f1_train: 0.816045 	f1_val: 0.387130
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.624081 	auc_val: 0.635150 	f1_train: 0.387070 	f1_val: 0.416938
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_under50_train.csv
# ----------------------------------------------------------------------
#  36%|███▌      | 10/28 [07:33<20:56, 69.79s/it]
# auc_train: 0.791243 	auc_val: 0.797873 	f1_train: 0.798396 	f1_val: 0.382789
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_over50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.791683 	auc_val: 0.795183 	f1_train: 0.798042 	f1_val: 0.380153
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_smote20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.668575 	auc_val: 0.678084 	f1_train: 0.482837 	f1_val: 0.449410
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_smote50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.806803 	auc_val: 0.797020 	f1_train: 0.813783 	f1_val: 0.388098
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_smoteTomek20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.684223 	auc_val: 0.680664 	f1_train: 0.512876 	f1_val: 0.462126
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_smoteTomek50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.808910 	auc_val: 0.795265 	f1_train: 0.815580 	f1_val: 0.386572
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.619803 	auc_val: 0.627705 	f1_train: 0.377483 	f1_val: 0.399011
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_under50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.793251 	auc_val: 0.798133 	f1_train: 0.800826 	f1_val: 0.381443
# ...
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_over50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.791197 	auc_val: 0.794997 	f1_train: 0.797358 	f1_val: 0.380411
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_smote20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.673835 	auc_val: 0.683947 	f1_train: 0.491698 	f1_val: 0.455650
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_smote50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.806554 	auc_val: 0.796398 	f1_train: 0.813413 	f1_val: 0.388166
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_smoteTomek20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.689747 	auc_val: 0.684248 	f1_train: 0.521490 	f1_val: 0.465788
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_smoteTomek50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.809375 	auc_val: 0.794706 	f1_train: 0.815972 	f1_val: 0.387410
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.628976 	auc_val: 0.640540 	f1_train: 0.397180 	f1_val: 0.427542
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_under50_train.csv
# ----------------------------------------------------------------------
#  89%|████████▉ | 25/28 [20:56<02:01, 40.53s/it]
# auc_train: 0.789904 	auc_val: 0.798697 	f1_train: 0.795889 	f1_val: 0.385614
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_over50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.791309 	auc_val: 0.794847 	f1_train: 0.797455 	f1_val: 0.380129
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_smote20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.674508 	auc_val: 0.685453 	f1_train: 0.493065 	f1_val: 0.457904
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_smote50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.806517 	auc_val: 0.796498 	f1_train: 0.813294 	f1_val: 0.388364
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_smoteTomek20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.689583 	auc_val: 0.686290 	f1_train: 0.521142 	f1_val: 0.469043
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_smoteTomek50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.808760 	auc_val: 0.795278 	f1_train: 0.815224 	f1_val: 0.387245
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.628453 	auc_val: 0.637764 	f1_train: 0.395968 	f1_val: 0.420546
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_under50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.790975 	auc_val: 0.798697 	f1_train: 0.796983 	f1_val: 0.385614
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_over50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.791210 	auc_val: 0.794947 	f1_train: 0.797368 	f1_val: 0.380317
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_smote20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.673785 	auc_val: 0.683947 	f1_train: 0.491617 	f1_val: 0.455650
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_smote50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.806554 	auc_val: 0.796398 	f1_train: 0.813413 	f1_val: 0.388166
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_smoteTomek20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.689747 	auc_val: 0.684248 	f1_train: 0.521490 	f1_val: 0.465788
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_smoteTomek50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.809362 	auc_val: 0.794706 	f1_train: 0.815958 	f1_val: 0.387410
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.628976 	auc_val: 0.640540 	f1_train: 0.397180 	f1_val: 0.427542
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_under50_train.csv
# ----------------------------------------------------------------------
#  93%|█████████▎| 26/28 [21:39<01:22, 41.22s/it]
# auc_train: 0.790037 	auc_val: 0.799382 	f1_train: 0.796046 	f1_val: 0.386307
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_over50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.791235 	auc_val: 0.794847 	f1_train: 0.797362 	f1_val: 0.380129
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_smote20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.674508 	auc_val: 0.685453 	f1_train: 0.493065 	f1_val: 0.457904
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_smote50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.806517 	auc_val: 0.796498 	f1_train: 0.813294 	f1_val: 0.388364
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_smoteTomek20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.689570 	auc_val: 0.686290 	f1_train: 0.521095 	f1_val: 0.469043
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_smoteTomek50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.808760 	auc_val: 0.795278 	f1_train: 0.815224 	f1_val: 0.387245
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.628453 	auc_val: 0.637764 	f1_train: 0.395968 	f1_val: 0.420546
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_under50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.790975 	auc_val: 0.798797 	f1_train: 0.796983 	f1_val: 0.385807
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_over50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.791185 	auc_val: 0.795147 	f1_train: 0.797319 	f1_val: 0.380693
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_smote20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.673835 	auc_val: 0.683947 	f1_train: 0.491698 	f1_val: 0.455650
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_smote50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.806542 	auc_val: 0.796398 	f1_train: 0.813399 	f1_val: 0.388166
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_smoteTomek20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.689804 	auc_val: 0.684248 	f1_train: 0.521576 	f1_val: 0.465788
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_smoteTomek50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.809362 	auc_val: 0.794706 	f1_train: 0.815958 	f1_val: 0.387410
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.628976 	auc_val: 0.640540 	f1_train: 0.397180 	f1_val: 0.427542
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_under50_train.csv
# ----------------------------------------------------------------------
#  96%|█████████▋| 27/28 [22:01<00:35, 35.51s/it]
# auc_train: 0.789770 	auc_val: 0.799332 	f1_train: 0.795733 	f1_val: 0.386210
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_over50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.791309 	auc_val: 0.794847 	f1_train: 0.797455 	f1_val: 0.380129
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_smote20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.674508 	auc_val: 0.685453 	f1_train: 0.493065 	f1_val: 0.457904
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_smote50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.806517 	auc_val: 0.796498 	f1_train: 0.813294 	f1_val: 0.388364
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_smoteTomek20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.689583 	auc_val: 0.686290 	f1_train: 0.521142 	f1_val: 0.469043
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_smoteTomek50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.808760 	auc_val: 0.795278 	f1_train: 0.815224 	f1_val: 0.387245
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.628453 	auc_val: 0.637764 	f1_train: 0.395968 	f1_val: 0.420546
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_under50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.790975 	auc_val: 0.798697 	f1_train: 0.796983 	f1_val: 0.385614
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_over50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.791210 	auc_val: 0.794947 	f1_train: 0.797368 	f1_val: 0.380317
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_smote20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.673785 	auc_val: 0.683947 	f1_train: 0.491617 	f1_val: 0.455650
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_smote50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.806554 	auc_val: 0.796398 	f1_train: 0.813413 	f1_val: 0.388166
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_smoteTomek20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.689747 	auc_val: 0.684248 	f1_train: 0.521490 	f1_val: 0.465788
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_smoteTomek50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.809362 	auc_val: 0.794706 	f1_train: 0.815958 	f1_val: 0.387410
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.628976 	auc_val: 0.640540 	f1_train: 0.397180 	f1_val: 0.427542
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_under50_train.csv
# ----------------------------------------------------------------------
# 100%|██████████| 28/28 [22:35<00:00, 48.42s/it]
# auc_train: 0.790037 	auc_val: 0.799382 	f1_train: 0.796046 	f1_val: 0.386307

# %%
df_results
# Out:
#                 preproc_label       model_label método  \
# 0        preprocess_v1_over50  xgboost_baseline    fit
# 1       preprocess_v1_smote20  xgboost_baseline    fit
# 2       preprocess_v1_smote50  xgboost_baseline    fit
# 3  preprocess_v1_smoteTomek20  xgboost_baseline    fit
# 4  preprocess_v1_smoteTomek50  xgboost_baseline    fit
#
#                                           parámetros columnas_out  auc_train  \
# 0  {'C': 0.001, 'penalty': 'l1', 'random_state': ...                0.772961
# 1  {'C': 0.001, 'penalty': 'l1', 'random_state': ...                0.543655
# 2  {'C': 0.001, 'penalty': 'l1', 'random_state': ...                0.788791
# 3  {'C': 0.001, 'penalty': 'l1', 'random_state': ...                0.540606
# 4  {'C': 0.001, 'penalty': 'l1', 'random_state': ...                0.792838
#
#     auc_val threshold  f1_train    f1_val
# 0  0.779456         1  0.784061  0.346537
# 1  0.551785         0  0.285704  0.157028
# 2  0.781288         1  0.802107  0.348910
# 3  0.548873         0  0.267336  0.157028
# 4  0.782408         1  0.805856  0.349722

# %%
MODELS = DATA/'models'

# %%
df_results.to_csv(f'{MODELS}/logistic_base.csv', index = False)

# %%
df_results.to_csv('logistic_base.csv')

# %%
df_results.to_excel(f'{MODELS}/logistic_base.xlsx', index = False)
