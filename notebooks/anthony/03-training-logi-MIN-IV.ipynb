# %% [markdown]
# # HR Analytics
#
# <img src = 'https://datahack-prod.s3.ap-south-1.amazonaws.com/__sized__/contest_cover/hr_1920x480_s5WuoZs-thumbnail-1200x1200-90.jpg'>
#
# Practice Problem: https://datahack.analyticsvidhya.com/contest/wns-analytics-hackathon-2018-1/

# %% [markdown]
# ## HR Analytics
#
# HR analytics is revolutionising the way human resources departments operate, leading to higher efficiency and better results overall. Human resources has been using analytics for years. However, the collection, processing and analysis of data has been largely manual, and given the nature of human resources dynamics and HR KPIs, the approach has been constraining HR. Therefore, it is surprising that HR departments woke up to the utility of machine learning so late in the game. Here is an opportunity to try predictive analytics in identifying the employees most likely to get promoted.

# %% [markdown]
# ## Problem Statement
#
# Your client is a large MNC and they have 9 broad verticals across the organisation. One of the problem your client is facing is around identifying the right people for promotion *(only for manager position and below)* and prepare them in time. Currently the process, they are following is:
#
# * They first identify a set of employees based on recommendations/ past performance
# * Selected employees go through the separate training and evaluation program for each vertical. These programs are based on the required skill of each vertical
# * At the end of the program, based on various factors such as training performance, KPI completion (only employees with KPIs completed greater than 60% are considered) etc., employee gets promotion
#
# For above mentioned process, the final promotions are only announced after the evaluation and this leads to delay in transition to their new roles. Hence, company needs your help in identifying the eligible candidates at a particular checkpoint so that they can expedite the entire promotion cycle.

# %% [markdown]
# <img src = 'https://s3-ap-south-1.amazonaws.com/av-blog-media/wp-content/uploads/2018/09/wns_hack_im_1.jpg'>

# %% [markdown]
# They have provided multiple attributes around Employee's past and current performance along with demographics. Now, The task is to predict whether a potential promotee at checkpoint in the test set will be promoted or not after the evaluation process.

# %% [markdown]
# ## Evaluation Metric
#
# The evaluation metric for this competition is F1 Score.
#
# ## Public and Private Split
#
# Test data is further randomly divided into Public (40%) and Private (60%) data.
#
# Your initial responses will be checked and scored on the Public data.
# The final rankings would be based on your private score which will be published once the competition is over.

# %% [markdown]
# ## Entorno

# %%
import sys
sys.version
# Out:
# '3.7.9 (default, Aug 31 2020, 17:10:11) [MSC v.1916 64 bit (AMD64)]'

# %%
# !conda info --envs
# Out:
# # conda environments:
# #
# base                  *  C:\Users\antho\Anaconda3

# %% [markdown]
# ## Paquetes

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import os
import numpy as np
import pandas as pd
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm, tqdm_notebook
from pathlib import Path
import random
import warnings
import pickle

warnings.filterwarnings('ignore')


seed = 2020
random.seed(seed)

pd.set_option('display.max_columns', 1000)
pd.set_option('display.max_rows', 400)
sns.set()

DATA = Path('../../data') 
RAW  = DATA/'raw'
PROCESSED = DATA/'processed'
SUBMISSIONS = DATA/'submissions'    

MODEL = Path('../../model')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
pd.__version__
# Out:
# '1.1.3'

# %%
np.__version__
# Out:
# '1.19.2'

# %%
sklearn.__version__
# Out:
# '0.23.2'

# %%
id_columns = 'employee_id'
target = 'is_promoted'

# %% [markdown]
# ## Lectura de datos

# %%
os.listdir(f'{PROCESSED}')
# Out:
# ['.DS_Store',
#  'preprocess_v1_capping_values.pkl',
#  'preprocess_v1_impute_values.pkl',
#  'preprocess_v1_ohe.pkl',
#  'preprocess_v1_ohe_columns.pkl',
#  'preprocess_v1_over50_train.csv',
#  'preprocess_v1_scaler.pkl',
#  'preprocess_v1_smote20_train.csv',
#  'preprocess_v1_smote50_train.csv',
#  'preprocess_v1_smoteTomek20_train.csv',
#  'preprocess_v1_smoteTomek50_train.csv',
#  'preprocess_v1_train.csv',
#  'preprocess_v1_under50_train.csv',
#  'preprocess_v1_val.csv',
#  'preprocess_v2_capping_values.pkl',
#  'preprocess_v2_knnimputation.pkl',
#  'preprocess_v2_ohe.pkl',
#  'preprocess_v2_ohe_columns.pkl',
#  'preprocess_v2_over50_train.csv',
#  'preprocess_v2_scaler.pkl',
#  'preprocess_v2_scalerimputation.pkl',
#  'preprocess_v2_smote20_train.csv',
#  'preprocess_v2_smote50_train.csv',
#  'preprocess_v2_smoteTomek20_train.csv',
#  'preprocess_v2_smoteTomek50_train.csv',
#  'preprocess_v2_test.csv',
#  'preprocess_v2_train.csv',
#  'preprocess_v2_under50_train.csv',
#  'preprocess_v2_val.csv']

# %% [markdown]
# ## Entrenamiento V1 sin balanceo

# %%
from sklearn.linear_model import LogisticRegression 
from sklearn.metrics import precision_recall_curve, roc_auc_score, f1_score

# %%
preproc_train = [file for file in os.listdir(f'{PROCESSED}') if file.endswith('train.csv')]
preproc_train
# Out:
# ['preprocess_v1_over50_train.csv',
#  'preprocess_v1_smote20_train.csv',
#  'preprocess_v1_smote50_train.csv',
#  'preprocess_v1_smoteTomek20_train.csv',
#  'preprocess_v1_smoteTomek50_train.csv',
#  'preprocess_v1_train.csv',
#  'preprocess_v1_under50_train.csv',
#  'preprocess_v2_over50_train.csv',
#  'preprocess_v2_smote20_train.csv',
#  'preprocess_v2_smote50_train.csv',
#  'preprocess_v2_smoteTomek20_train.csv',
#  'preprocess_v2_smoteTomek50_train.csv',
#  'preprocess_v2_train.csv',
#  'preprocess_v2_under50_train.csv']

# %%
preproc_val = [file for file in os.listdir(f'{PROCESSED}') if file.endswith('val.csv')]
preproc_val
# Out:
# ['preprocess_v1_val.csv', 'preprocess_v2_val.csv']

# %%
for train_file in sorted(preproc_train):
    df_train = pd.read_csv(f'{PROCESSED}/{train_file}', compression = 'zip')
    df_val = pd.read_csv(f'{PROCESSED}/{preproc_val[0]}', compression = 'zip')
    
    print(f'label: {train_file:35} \tnrows: {len(df_train)} \t%target train: {df_train[target].mean():.4f} \t%target val: {df_val[target].mean():.4f}')
# Out:
# label: preprocess_v1_over50_train.csv      	nrows: 80224 	%target train: 0.5000 	%target val: 0.0852
# label: preprocess_v1_smote20_train.csv     	nrows: 48134 	%target train: 0.1667 	%target val: 0.0852
# label: preprocess_v1_smote50_train.csv     	nrows: 80224 	%target train: 0.5000 	%target val: 0.0852
# label: preprocess_v1_smoteTomek20_train.csv 	nrows: 46412 	%target train: 0.1543 	%target val: 0.0852
# label: preprocess_v1_smoteTomek50_train.csv 	nrows: 79638 	%target train: 0.5000 	%target val: 0.0852
# label: preprocess_v1_train.csv             	nrows: 43846 	%target train: 0.0852 	%target val: 0.0852
# label: preprocess_v1_under50_train.csv     	nrows: 7468 	%target train: 0.5000 	%target val: 0.0852
# label: preprocess_v2_over50_train.csv      	nrows: 80224 	%target train: 0.5000 	%target val: 0.0852
# label: preprocess_v2_smote20_train.csv     	nrows: 48134 	%target train: 0.1667 	%target val: 0.0852
# label: preprocess_v2_smote50_train.csv     	nrows: 80224 	%target train: 0.5000 	%target val: 0.0852
# label: preprocess_v2_smoteTomek20_train.csv 	nrows: 46390 	%target train: 0.1541 	%target val: 0.0852
# label: preprocess_v2_smoteTomek50_train.csv 	nrows: 79638 	%target train: 0.5000 	%target val: 0.0852
# label: preprocess_v2_train.csv             	nrows: 43846 	%target train: 0.0852 	%target val: 0.0852
# label: preprocess_v2_under50_train.csv     	nrows: 7468 	%target train: 0.5000 	%target val: 0.0852

# %%
train_file = 'preprocess_v1_train.csv'
val_file = 'preprocess_v1_val.csv'
df_val.head()
# Out:
#    no_of_trainings       age  previous_year_rating  length_of_service  \
# 0        -0.431999 -1.019219              0.550807          -0.939230
# 1        -0.431999  1.326548             -0.273747           2.990067
# 2         1.325254  0.153664             -1.098300          -0.693649
# 3        -0.431999 -0.888899              1.375360          -0.202487
# 4        -0.431999 -0.106976             -1.098300           1.025418
#
#    KPIs_met >80%  awards_won?  avg_training_score  na_previous_year_rating  \
# 0      -0.737109    -0.153163            0.420470                -0.284445
# 1      -0.737109    -0.153163            0.270731                -0.284445
# 2      -0.737109    -0.153163            1.393774                -0.284445
# 3       1.356651    -0.153163            0.869688                -0.284445
# 4       1.356651    -0.153163           -0.852312                -0.284445
#
#    na_education  department_Analytics  department_Finance  department_HR  \
# 0     -0.212536             -0.328940           -0.220673       -0.21574
# 1     -0.212536             -0.328940           -0.220673       -0.21574
# 2     -0.212536              3.040066           -0.220673       -0.21574
# 3     -0.212536             -0.328940           -0.220673       -0.21574
# 4     -0.212536             -0.328940           -0.220673       -0.21574
#
#    department_Legal  department_Operations  department_Procurement  \
# 0         -0.137364              -0.509846                2.582520
# 1         -0.137364              -0.509846                2.582520
# 2         -0.137364              -0.509846               -0.387219
# 3         -0.137364              -0.509846               -0.387219
# 4         -0.137364              -0.509846               -0.387219
#
#    department_R&D  department_Sales & Marketing  department_Technology  \
# 0       -0.135368                     -0.666307              -0.387881
# 1       -0.135368                     -0.666307              -0.387881
# 2       -0.135368                     -0.666307              -0.387881
# 3       -0.135368                     -0.666307               2.578113
# 4       -0.135368                      1.500810              -0.387881
#
#    region_region_1  region_region_10  region_region_11  region_region_12  \
# 0        -0.106419         -0.110615         -0.155332         -0.094979
# 1        -0.106419         -0.110615         -0.155332         -0.094979
# 2        -0.106419         -0.110615         -0.155332         -0.094979
# 3         9.396775         -0.110615         -0.155332         -0.094979
# 4        -0.106419         -0.110615         -0.155332         -0.094979
#
#    region_region_13  region_region_14  region_region_15  region_region_16  \
# 0         -0.222429         -0.125042         -0.232522         -0.166592
# 1         -0.222429         -0.125042          4.300672         -0.166592
# 2         -0.222429         -0.125042         -0.232522         -0.166592
# 3         -0.222429         -0.125042         -0.232522         -0.166592
# 4         -0.222429         -0.125042         -0.232522         -0.166592
#
#    region_region_17  region_region_18  region_region_19  region_region_2  \
# 0         -0.122189         -0.024823         -0.126818        -0.537077
# 1         -0.122189         -0.024823         -0.126818        -0.537077
# 2         -0.122189         -0.024823         -0.126818        -0.537077
# 3         -0.122189         -0.024823         -0.126818        -0.537077
# 4         -0.122189         -0.024823         -0.126818        -0.537077
#
#    region_region_20  region_region_21  region_region_22  region_region_23  \
# 0         -0.125886         -0.085878         -0.363769          6.719649
# 1         -0.125886         -0.085878         -0.363769         -0.148817
# 2         -0.125886         -0.085878         -0.363769         -0.148817
# 3         -0.125886         -0.085878         -0.363769         -0.148817
# 4         -0.125886         -0.085878         -0.363769         -0.148817
#
#    region_region_24  region_region_25  region_region_26  region_region_27  \
# 0         -0.096073         -0.123338         -0.205222         -0.177348
# 1         -0.096073         -0.123338         -0.205222         -0.177348
# 2         -0.096073         -0.123338         -0.205222         -0.177348
# 3         -0.096073         -0.123338         -0.205222         -0.177348
# 4         -0.096073         -0.123338         -0.205222         -0.177348
#
#    region_region_28  region_region_29  region_region_3  region_region_30  \
# 0         -0.157475         -0.137364        -0.080456          -0.10934
# 1         -0.157475         -0.137364        -0.080456          -0.10934
# 2         -0.157475         -0.137364        -0.080456          -0.10934
# 3         -0.157475         -0.137364        -0.080456          -0.10934
# 4         -0.157475         -0.137364        -0.080456          -0.10934
#
#    region_region_31  region_region_32  region_region_33  region_region_34  \
# 0         -0.193472         -0.130933         -0.071013         -0.071175
# 1         -0.193472         -0.130933         -0.071013         -0.071175
# 2         -0.193472          7.637508         -0.071013         -0.071175
# 3         -0.193472         -0.130933         -0.071013         -0.071175
# 4         -0.193472         -0.130933         -0.071013         -0.071175
#
#    region_region_4  region_region_5  region_region_6  region_region_7  \
# 0        -0.180403         -0.12103        -0.111771        -0.313120
# 1        -0.180403         -0.12103        -0.111771        -0.313120
# 2        -0.180403         -0.12103        -0.111771        -0.313120
# 3        -0.180403         -0.12103        -0.111771        -0.313120
# 4        -0.180403         -0.12103        -0.111771         3.193664
#
#    region_region_8  region_region_9  education_Bachelor's  \
# 0        -0.112084        -0.089315              0.634349
# 1        -0.112084        -0.089315             -1.576419
# 2        -0.112084        -0.089315              0.634349
# 3        -0.112084        -0.089315              0.634349
# 4        -0.112084        -0.089315              0.634349
#
#    education_Below Secondary  education_Master's & above  gender_f  gender_m  \
# 0                  -0.120154                   -0.612337 -0.651463  0.651463
# 1                  -0.120154                    1.633087 -0.651463  0.651463
# 2                  -0.120154                   -0.612337 -0.651463  0.651463
# 3                  -0.120154                   -0.612337  1.535007 -1.535007
# 4                  -0.120154                   -0.612337  1.535007 -1.535007
#
#    recruitment_channel_other  recruitment_channel_referred  \
# 0                   0.892730                     -0.145991
# 1                   0.892730                     -0.145991
# 2                   0.892730                     -0.145991
# 3                  -1.120159                     -0.145991
# 4                  -1.120159                     -0.145991
#
#    recruitment_channel_sourcing  is_promoted
# 0                     -0.855580            0
# 1                     -0.855580            0
# 2                     -0.855580            0
# 3                      1.168798            0
# 4                      1.168798            0

# %%
#df_train.drop(target, axis = 1)

dele= ['education','age','no_of_tra','recruitm','length','gender','empl']
for a in dele :
    df_val=df_val[df_train.columns.drop(list(df_train.filter(regex=a)))].head()

# %%
from sklearn.model_selection import ParameterGrid

# %%
cv_grid = {'penalty': ['l1','l2'],'solver': ['liblinear','saga'],
              'C': [0.001,0.01,0.1,1,10,100,1000],
            'random_state': [seed]}

params_grid = list(ParameterGrid(cv_grid))

# %%
df_results = pd.DataFrame(columns = ['preproc_label', 'model_label', 'método', 'parámetros', 'columnas_out',
                                     'auc_train', 'auc_val', 'threshold','f1_train', 'f1_val'])


for xgb_params in tqdm(params_grid):
    
    for train_file in sorted(preproc_train):

        preproc_label = train_file.split('_train')[0]

        print('----------------------------------------------------------------------')
        print(xgb_params)
        print(train_file)
        print('----------------------------------------------------------------------')

        df_train = pd.read_csv(f'{PROCESSED}/{train_file}', compression = 'zip')
        df_val = pd.read_csv(f'{PROCESSED}/{preproc_val[0]}', compression = 'zip')

        
        dele= ['education','age','no_of_tra','recruitm','length','gender','empl']
        for a in dele :
            df_train=df_train[df_train.columns.drop(list(df_train.filter(regex=a)))]
            df_val=df_val[df_val.columns.drop(list(df_val.filter(regex=a)))]
        
        
        X_train, y_train = df_train.drop(target, axis = 1), df_train[target]
        X_val, y_val = df_val.drop(target, axis = 1), df_val[target]

        logi = LogisticRegression(solver = xgb_params["solver"],penalty =xgb_params["penalty"], C =xgb_params["C"], random_state= xgb_params["random_state"])
        logi_fit = logi.fit( X_train,y_train )
                        
        
        #xgb_params_export = xgb_params.copy()
        #xgb_params_export.update(logi_fit.attributes())

        probs_train = logi_fit.predict(X_train)
        probs_val = logi_fit.predict(X_val)

        auc_train = roc_auc_score(y_train, probs_train)
        auc_val = roc_auc_score(y_val, probs_val)

        #best threshold
        prec, recall, threshold = precision_recall_curve(y_train, probs_train)
        prec_recall = pd.DataFrame({'prec': prec[:-1], 'recall': recall[:-1], 'threshold': threshold})
        prec_recall['f1'] = 2*prec_recall['prec']*prec_recall['recall'] / (prec_recall['prec'] + prec_recall['recall'])
        prec_recall = prec_recall.sort_values(by = 'f1', ascending = False).head(1)

        #f1 scores
        best_threshold = prec_recall['threshold'].values[0]
        f1_train = prec_recall['f1'].values[0]

        labels_val = np.where(probs_val >= best_threshold, 1, 0)
        f1_val = f1_score(y_val, labels_val)

        print(f'auc_train: {auc_train:.6f} \tauc_val: {auc_val:.6f} \tf1_train: {f1_train:.6f} \tf1_val: {f1_val:.6f}')

        results = [preproc_label, 'xgboost_baseline', 'fit', xgb_params, '',
                  auc_train, auc_val, best_threshold, f1_train, f1_val]


        df_results.loc[len(df_results)] = results
# Out:
#   0%|          | 0/28 [00:00<?, ?it/s]
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_over50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.772961 	auc_val: 0.779456 	f1_train: 0.784061 	f1_val: 0.346537
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_smote20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.543655 	auc_val: 0.551785 	f1_train: 0.285704 	f1_val: 0.157028
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_smote50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.787844 	auc_val: 0.781960 	f1_train: 0.801094 	f1_val: 0.349023
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_smoteTomek20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.540606 	auc_val: 0.548873 	f1_train: 0.267336 	f1_val: 0.157028
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_smoteTomek50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.792574 	auc_val: 0.780117 	f1_train: 0.805592 	f1_val: 0.348020
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.500000 	auc_val: 0.500000 	f1_train: 0.156957 	f1_val: 0.157028
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_under50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.713846 	auc_val: 0.712636 	f1_train: 0.723866 	f1_val: 0.286592
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_over50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.772662 	auc_val: 0.779656 	f1_train: 0.783843 	f1_val: 0.346844
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_smote20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.543643 	auc_val: 0.551785 	f1_train: 0.285704 	f1_val: 0.157028
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_smote50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.787844 	auc_val: 0.779745 	f1_train: 0.801191 	f1_val: 0.348370
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_smoteTomek20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.540088 	auc_val: 0.548337 	f1_train: 0.267090 	f1_val: 0.157028
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_smoteTomek50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.792787 	auc_val: 0.780666 	f1_train: 0.805809 	f1_val: 0.348874
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.500000 	auc_val: 0.500000 	f1_train: 0.156957 	f1_val: 0.157028
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_under50_train.csv
# ----------------------------------------------------------------------
#   4%|▎         | 1/28 [00:18<08:29, 18.87s/it]
# auc_train: 0.713846 	auc_val: 0.712636 	f1_train: 0.723866 	f1_val: 0.286592
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_over50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.766117 	auc_val: 0.777858 	f1_train: 0.773844 	f1_val: 0.351086
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_smote20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.540414 	auc_val: 0.548337 	f1_train: 0.285704 	f1_val: 0.157028
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_smote50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.780515 	auc_val: 0.774334 	f1_train: 0.790963 	f1_val: 0.347846
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_smoteTomek20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.537212 	auc_val: 0.542847 	f1_train: 0.267336 	f1_val: 0.157028
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_smoteTomek50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.785617 	auc_val: 0.772219 	f1_train: 0.795579 	f1_val: 0.347327
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.500937 	auc_val: 0.501606 	f1_train: 0.156957 	f1_val: 0.157028
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_under50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.713444 	auc_val: 0.711941 	f1_train: 0.722726 	f1_val: 0.286892
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_over50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.765706 	auc_val: 0.777223 	f1_train: 0.773619 	f1_val: 0.350548
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_smote20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.540938 	auc_val: 0.547852 	f1_train: 0.285704 	f1_val: 0.157028
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_smote50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.780240 	auc_val: 0.775517 	f1_train: 0.790727 	f1_val: 0.349257
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_smoteTomek20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.537610 	auc_val: 0.543968 	f1_train: 0.267090 	f1_val: 0.157028
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_smoteTomek50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.785781 	auc_val: 0.772032 	f1_train: 0.795821 	f1_val: 0.347506
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.501071 	auc_val: 0.501606 	f1_train: 0.156957 	f1_val: 0.157028
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_under50_train.csv
# ----------------------------------------------------------------------
#   7%|▋         | 2/28 [00:40<08:32, 19.73s/it]
# auc_train: 0.713444 	auc_val: 0.711941 	f1_train: 0.722726 	f1_val: 0.286892
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_over50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.779355 	auc_val: 0.782002 	f1_train: 0.789291 	f1_val: 0.352409
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_smote20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.588831 	auc_val: 0.606799 	f1_train: 0.303479 	f1_val: 0.335743
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_smote50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.794251 	auc_val: 0.778204 	f1_train: 0.806486 	f1_val: 0.349717
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_smoteTomek20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.592822 	auc_val: 0.604085 	f1_train: 0.312927 	f1_val: 0.330350
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_smoteTomek50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.796027 	auc_val: 0.779711 	f1_train: 0.807791 	f1_val: 0.350679
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.546134 	auc_val: 0.556868 	f1_train: 0.168980 	f1_val: 0.203582
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_under50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.757499 	auc_val: 0.755195 	f1_train: 0.773313 	f1_val: 0.317329
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_over50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.778907 	auc_val: 0.781367 	f1_train: 0.788993 	f1_val: 0.351877
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_smote20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.588694 	auc_val: 0.607384 	f1_train: 0.303109 	f1_val: 0.337349
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_smote50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.793952 	auc_val: 0.777097 	f1_train: 0.806236 	f1_val: 0.349387
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_smoteTomek20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.593340 	auc_val: 0.603550 	f1_train: 0.314305 	f1_val: 0.328990
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_smoteTomek50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.796090 	auc_val: 0.779189 	f1_train: 0.807952 	f1_val: 0.350806
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.546657 	auc_val: 0.556868 	f1_train: 0.170691 	f1_val: 0.203582
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_under50_train.csv
# ----------------------------------------------------------------------
#  11%|█         | 3/28 [00:58<08:01, 19.26s/it]
# auc_train: 0.757633 	auc_val: 0.753203 	f1_train: 0.773297 	f1_val: 0.316137
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_over50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.774107 	auc_val: 0.777861 	f1_train: 0.781784 	f1_val: 0.353050
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_smote20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.581638 	auc_val: 0.598931 	f1_train: 0.285704 	f1_val: 0.157028
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_smote50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.788891 	auc_val: 0.776318 	f1_train: 0.798989 	f1_val: 0.352505
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_smoteTomek20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.585367 	auc_val: 0.596032 	f1_train: 0.292353 	f1_val: 0.312343
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_smoteTomek50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.791381 	auc_val: 0.776068 	f1_train: 0.801049 	f1_val: 0.352096
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.537863 	auc_val: 0.539838 	f1_train: 0.156957 	f1_val: 0.157028
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_under50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.740627 	auc_val: 0.741587 	f1_train: 0.743274 	f1_val: 0.321542
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_over50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.773758 	auc_val: 0.777525 	f1_train: 0.781557 	f1_val: 0.352996
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_smote20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.581476 	auc_val: 0.598595 	f1_train: 0.285704 	f1_val: 0.157028
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_smote50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.788704 	auc_val: 0.776281 	f1_train: 0.798870 	f1_val: 0.352941
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_smoteTomek20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.585256 	auc_val: 0.596032 	f1_train: 0.292034 	f1_val: 0.312343
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_smoteTomek50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.791544 	auc_val: 0.776703 	f1_train: 0.801326 	f1_val: 0.352641
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.537449 	auc_val: 0.539838 	f1_train: 0.156957 	f1_val: 0.157028
# ----------------------------------------------------------------------
# {'C': 0.001, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_under50_train.csv
# ----------------------------------------------------------------------
#  14%|█▍        | 4/28 [01:18<07:47, 19.47s/it]
# auc_train: 0.740761 	auc_val: 0.741713 	f1_train: 0.743304 	f1_val: 0.322536
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_over50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.788579 	auc_val: 0.797681 	f1_train: 0.795525 	f1_val: 0.378208
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_smote20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.642546 	auc_val: 0.655469 	f1_train: 0.432858 	f1_val: 0.424284
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_smote50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.803961 	auc_val: 0.799516 	f1_train: 0.812244 	f1_val: 0.383440
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_smoteTomek20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.654556 	auc_val: 0.654873 	f1_train: 0.458517 	f1_val: 0.429071
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_smoteTomek50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.806299 	auc_val: 0.800836 	f1_train: 0.814019 	f1_val: 0.384710
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.584035 	auc_val: 0.593421 	f1_train: 0.285779 	f1_val: 0.312611
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_under50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.769952 	auc_val: 0.779456 	f1_train: 0.781703 	f1_val: 0.346537
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_over50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.788480 	auc_val: 0.797482 	f1_train: 0.795626 	f1_val: 0.377842
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_smote20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.641786 	auc_val: 0.656689 	f1_train: 0.431122 	f1_val: 0.427304
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_smote50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.803587 	auc_val: 0.800114 	f1_train: 0.811751 	f1_val: 0.384577
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_smoteTomek20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.655072 	auc_val: 0.654973 	f1_train: 0.459761 	f1_val: 0.429671
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_smoteTomek50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.806763 	auc_val: 0.801471 	f1_train: 0.814610 	f1_val: 0.385298
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.584571 	auc_val: 0.593956 	f1_train: 0.287323 	f1_val: 0.314108
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_under50_train.csv
# ----------------------------------------------------------------------
#  18%|█▊        | 5/28 [02:06<10:44, 28.01s/it]
# auc_train: 0.769282 	auc_val: 0.777467 	f1_train: 0.780649 	f1_val: 0.347144
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_over50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.787794 	auc_val: 0.797109 	f1_train: 0.794351 	f1_val: 0.378339
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_smote20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.641811 	auc_val: 0.653963 	f1_train: 0.431300 	f1_val: 0.421629
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_smote50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.803089 	auc_val: 0.799043 	f1_train: 0.811056 	f1_val: 0.383778
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_smoteTomek20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.654543 	auc_val: 0.655309 	f1_train: 0.458472 	f1_val: 0.429568
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_smoteTomek50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.805646 	auc_val: 0.801235 	f1_train: 0.813158 	f1_val: 0.385471
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.584120 	auc_val: 0.593371 	f1_train: 0.285907 	f1_val: 0.312334
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_under50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.759909 	auc_val: 0.771075 	f1_train: 0.766992 	f1_val: 0.347405
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_over50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.788480 	auc_val: 0.796724 	f1_train: 0.795433 	f1_val: 0.378221
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_smote20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.641000 	auc_val: 0.653577 	f1_train: 0.429410 	f1_val: 0.421414
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_smote50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.803438 	auc_val: 0.797277 	f1_train: 0.811274 	f1_val: 0.384136
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_smoteTomek20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.654780 	auc_val: 0.654923 	f1_train: 0.459113 	f1_val: 0.429371
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_smoteTomek50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.805985 	auc_val: 0.801098 	f1_train: 0.813500 	f1_val: 0.385835
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.584546 	auc_val: 0.593421 	f1_train: 0.287193 	f1_val: 0.312611
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_under50_train.csv
# ----------------------------------------------------------------------
#  21%|██▏       | 6/28 [02:53<12:17, 33.53s/it]
# auc_train: 0.760846 	auc_val: 0.770775 	f1_train: 0.768172 	f1_val: 0.346925
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_over50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.788592 	auc_val: 0.797492 	f1_train: 0.795854 	f1_val: 0.376109
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_smote20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.634182 	auc_val: 0.648037 	f1_train: 0.414751 	f1_val: 0.411397
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_smote50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.804622 	auc_val: 0.800710 	f1_train: 0.813418 	f1_val: 0.383239
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_smoteTomek20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.643679 	auc_val: 0.641603 	f1_train: 0.435521 	f1_val: 0.403736
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_smoteTomek50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.806964 	auc_val: 0.799925 	f1_train: 0.815137 	f1_val: 0.382375
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.581575 	auc_val: 0.591715 	f1_train: 0.278544 	f1_val: 0.307556
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_under50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.780664 	auc_val: 0.780259 	f1_train: 0.791391 	f1_val: 0.351554
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_over50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.788966 	auc_val: 0.798190 	f1_train: 0.796122 	f1_val: 0.377377
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_smote20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.633608 	auc_val: 0.647216 	f1_train: 0.413528 	f1_val: 0.410615
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_smote50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.804510 	auc_val: 0.802129 	f1_train: 0.813260 	f1_val: 0.384691
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_smoteTomek20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.644343 	auc_val: 0.641802 	f1_train: 0.436982 	f1_val: 0.404899
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_smoteTomek50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.807102 	auc_val: 0.801880 	f1_train: 0.815387 	f1_val: 0.384220
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.581320 	auc_val: 0.592300 	f1_train: 0.277828 	f1_val: 0.309333
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_under50_train.csv
# ----------------------------------------------------------------------
#  25%|██▌       | 7/28 [03:13<10:24, 29.73s/it]
# auc_train: 0.780396 	auc_val: 0.779551 	f1_train: 0.790870 	f1_val: 0.351869
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_over50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.788991 	auc_val: 0.797569 	f1_train: 0.796073 	f1_val: 0.377413
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_smote20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.632374 	auc_val: 0.647066 	f1_train: 0.410729 	f1_val: 0.409756
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_smote50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.804635 	auc_val: 0.799516 	f1_train: 0.813032 	f1_val: 0.383440
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_smoteTomek20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.642403 	auc_val: 0.641118 	f1_train: 0.432719 	f1_val: 0.402878
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_smoteTomek50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.806437 	auc_val: 0.799739 	f1_train: 0.814396 	f1_val: 0.382634
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.580613 	auc_val: 0.590594 	f1_train: 0.275690 	f1_val: 0.304270
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_under50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.773701 	auc_val: 0.777501 	f1_train: 0.782048 	f1_val: 0.353953
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_over50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.788006 	auc_val: 0.795603 	f1_train: 0.794837 	f1_val: 0.377340
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_smote20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.631651 	auc_val: 0.646581 	f1_train: 0.409136 	f1_val: 0.408932
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_smote50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.804248 	auc_val: 0.799379 	f1_train: 0.812660 	f1_val: 0.383798
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_smoteTomek20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.642995 	auc_val: 0.640831 	f1_train: 0.434025 	f1_val: 0.403179
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_smoteTomek50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.806336 	auc_val: 0.800872 	f1_train: 0.814389 	f1_val: 0.384161
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.580479 	auc_val: 0.590594 	f1_train: 0.275300 	f1_val: 0.304270
# ----------------------------------------------------------------------
# {'C': 0.01, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_under50_train.csv
# ----------------------------------------------------------------------
#  29%|██▊       | 8/28 [03:37<09:20, 28.01s/it]
# auc_train: 0.773299 	auc_val: 0.774116 	f1_train: 0.781520 	f1_val: 0.352363
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_over50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.788056 	auc_val: 0.798233 	f1_train: 0.794100 	f1_val: 0.381631
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_smote20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.667528 	auc_val: 0.681509 	f1_train: 0.480626 	f1_val: 0.458463
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_smote50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.803101 	auc_val: 0.793656 	f1_train: 0.810217 	f1_val: 0.382797
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_smoteTomek20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.682286 	auc_val: 0.681249 	f1_train: 0.508567 	f1_val: 0.463399
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_smoteTomek50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.805369 	auc_val: 0.795561 	f1_train: 0.811921 	f1_val: 0.384596
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.625084 	auc_val: 0.630768 	f1_train: 0.390324 	f1_val: 0.405892
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_under50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.787359 	auc_val: 0.800720 	f1_train: 0.795202 	f1_val: 0.381438
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_over50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.788230 	auc_val: 0.798033 	f1_train: 0.794499 	f1_val: 0.381256
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_smote20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.666979 	auc_val: 0.680787 	f1_train: 0.479263 	f1_val: 0.458543
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_smote50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.802790 	auc_val: 0.793569 	f1_train: 0.809960 	f1_val: 0.383258
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_smoteTomek20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.682400 	auc_val: 0.681448 	f1_train: 0.508998 	f1_val: 0.464582
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_smoteTomek50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.805018 	auc_val: 0.795026 	f1_train: 0.811695 	f1_val: 0.384189
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.624511 	auc_val: 0.631303 	f1_train: 0.388764 	f1_val: 0.407195
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_under50_train.csv
# ----------------------------------------------------------------------
#  32%|███▏      | 9/28 [05:22<16:09, 51.04s/it]
# auc_train: 0.787895 	auc_val: 0.799862 	f1_train: 0.795929 	f1_val: 0.381650
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_over50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.788081 	auc_val: 0.798233 	f1_train: 0.794119 	f1_val: 0.381631
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_smote20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.667528 	auc_val: 0.681509 	f1_train: 0.480626 	f1_val: 0.458463
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_smote50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.803039 	auc_val: 0.793806 	f1_train: 0.810137 	f1_val: 0.383086
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_smoteTomek20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.682185 	auc_val: 0.681299 	f1_train: 0.508435 	f1_val: 0.463694
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_smoteTomek50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.805332 	auc_val: 0.795561 	f1_train: 0.811873 	f1_val: 0.384596
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.624766 	auc_val: 0.630668 	f1_train: 0.389344 	f1_val: 0.405229
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_under50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.786690 	auc_val: 0.800733 	f1_train: 0.794319 	f1_val: 0.382066
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_over50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.788093 	auc_val: 0.798033 	f1_train: 0.794323 	f1_val: 0.381256
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_smote20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.667041 	auc_val: 0.680252 	f1_train: 0.479387 	f1_val: 0.457574
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_smote50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.802653 	auc_val: 0.793234 	f1_train: 0.809794 	f1_val: 0.383237
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_smoteTomek20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.682285 	auc_val: 0.681498 	f1_train: 0.508820 	f1_val: 0.464879
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_smoteTomek50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.804993 	auc_val: 0.795026 	f1_train: 0.811662 	f1_val: 0.384189
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.624498 	auc_val: 0.630668 	f1_train: 0.388684 	f1_val: 0.405229
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_under50_train.csv
# ----------------------------------------------------------------------
#  36%|███▌      | 10/28 [06:41<17:49, 59.43s/it]
# auc_train: 0.787225 	auc_val: 0.798605 	f1_train: 0.794941 	f1_val: 0.381115
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_over50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.788941 	auc_val: 0.798655 	f1_train: 0.795394 	f1_val: 0.381209
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_smote20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.664498 	auc_val: 0.677425 	f1_train: 0.474955 	f1_val: 0.451857
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_smote50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.803425 	auc_val: 0.794042 	f1_train: 0.810689 	f1_val: 0.382915
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_smoteTomek20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.680003 	auc_val: 0.676544 	f1_train: 0.505211 	f1_val: 0.457364
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_smoteTomek50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.805394 	auc_val: 0.795498 	f1_train: 0.812141 	f1_val: 0.383843
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.620572 	auc_val: 0.627656 	f1_train: 0.379789 	f1_val: 0.398682
# ----------------------------------------------------------------------
# {'C': 0.1, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_under50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.786690 	auc_val: 0.800720 	f1_train: 0.794425 	f1_val: 0.381438
# ...
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_over50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.788056 	auc_val: 0.797361 	f1_train: 0.794235 	f1_val: 0.381210
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_smote20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.669285 	auc_val: 0.684708 	f1_train: 0.483250 	f1_val: 0.462014
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_smote50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.802491 	auc_val: 0.792648 	f1_train: 0.809576 	f1_val: 0.382732
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_smoteTomek20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.685221 	auc_val: 0.683091 	f1_train: 0.513523 	f1_val: 0.465528
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_smoteTomek50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.804679 	auc_val: 0.795076 	f1_train: 0.811269 	f1_val: 0.384286
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.628154 	auc_val: 0.635623 	f1_train: 0.396192 	f1_val: 0.415459
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l1', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_under50_train.csv
# ----------------------------------------------------------------------
#  89%|████████▉ | 25/28 [16:30<01:29, 29.98s/it]
# auc_train: 0.788029 	auc_val: 0.800623 	f1_train: 0.795346 	f1_val: 0.383690
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_over50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.787221 	auc_val: 0.798345 	f1_train: 0.792925 	f1_val: 0.382454
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_smote20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.669834 	auc_val: 0.683238 	f1_train: 0.484534 	f1_val: 0.457846
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_smote50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.802977 	auc_val: 0.793756 	f1_train: 0.809978 	f1_val: 0.382989
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_smoteTomek20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.685573 	auc_val: 0.682556 	f1_train: 0.514311 	f1_val: 0.464557
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_smoteTomek50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.804930 	auc_val: 0.795661 	f1_train: 0.811388 	f1_val: 0.384790
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.628459 	auc_val: 0.635573 	f1_train: 0.397083 	f1_val: 0.415125
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_under50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.787895 	auc_val: 0.801095 	f1_train: 0.795031 	f1_val: 0.383354
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_over50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.788056 	auc_val: 0.797361 	f1_train: 0.794235 	f1_val: 0.381210
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_smote20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.669285 	auc_val: 0.684708 	f1_train: 0.483250 	f1_val: 0.462014
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_smote50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.802491 	auc_val: 0.792648 	f1_train: 0.809576 	f1_val: 0.382732
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_smoteTomek20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.685151 	auc_val: 0.683091 	f1_train: 0.513389 	f1_val: 0.465528
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_smoteTomek50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.804679 	auc_val: 0.795076 	f1_train: 0.811269 	f1_val: 0.384286
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.628154 	auc_val: 0.635623 	f1_train: 0.396192 	f1_val: 0.415459
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l1', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_under50_train.csv
# ----------------------------------------------------------------------
#  93%|█████████▎| 26/28 [17:02<01:01, 30.56s/it]
# auc_train: 0.787761 	auc_val: 0.800623 	f1_train: 0.795087 	f1_val: 0.383690
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_over50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.787221 	auc_val: 0.798345 	f1_train: 0.792925 	f1_val: 0.382454
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_smote20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.669896 	auc_val: 0.683238 	f1_train: 0.484657 	f1_val: 0.457846
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_smote50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.802977 	auc_val: 0.793756 	f1_train: 0.809978 	f1_val: 0.382989
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_smoteTomek20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.685700 	auc_val: 0.683091 	f1_train: 0.514533 	f1_val: 0.465528
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_smoteTomek50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.804930 	auc_val: 0.795661 	f1_train: 0.811388 	f1_val: 0.384790
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.628459 	auc_val: 0.635573 	f1_train: 0.397083 	f1_val: 0.415125
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v1_under50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.787895 	auc_val: 0.801145 	f1_train: 0.795031 	f1_val: 0.383448
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_over50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.788056 	auc_val: 0.797361 	f1_train: 0.794235 	f1_val: 0.381210
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_smote20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.669348 	auc_val: 0.684708 	f1_train: 0.483372 	f1_val: 0.462014
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_smote50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.802478 	auc_val: 0.792648 	f1_train: 0.809562 	f1_val: 0.382732
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_smoteTomek20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.685208 	auc_val: 0.683091 	f1_train: 0.513477 	f1_val: 0.465528
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_smoteTomek50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.804691 	auc_val: 0.795076 	f1_train: 0.811284 	f1_val: 0.384286
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.628154 	auc_val: 0.635623 	f1_train: 0.396192 	f1_val: 0.415459
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l2', 'random_state': 2020, 'solver': 'liblinear'}
# preprocess_v2_under50_train.csv
# ----------------------------------------------------------------------
#  96%|█████████▋| 27/28 [17:23<00:27, 27.75s/it]
# auc_train: 0.788029 	auc_val: 0.800623 	f1_train: 0.795346 	f1_val: 0.383690
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_over50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.787221 	auc_val: 0.798345 	f1_train: 0.792925 	f1_val: 0.382454
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_smote20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.669834 	auc_val: 0.683238 	f1_train: 0.484534 	f1_val: 0.457846
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_smote50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.802977 	auc_val: 0.793756 	f1_train: 0.809978 	f1_val: 0.382989
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_smoteTomek20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.685573 	auc_val: 0.682556 	f1_train: 0.514311 	f1_val: 0.464557
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_smoteTomek50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.804930 	auc_val: 0.795661 	f1_train: 0.811388 	f1_val: 0.384790
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.628459 	auc_val: 0.635573 	f1_train: 0.397083 	f1_val: 0.415125
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v1_under50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.787895 	auc_val: 0.801095 	f1_train: 0.795031 	f1_val: 0.383354
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_over50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.788056 	auc_val: 0.797361 	f1_train: 0.794235 	f1_val: 0.381210
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_smote20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.669285 	auc_val: 0.684708 	f1_train: 0.483250 	f1_val: 0.462014
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_smote50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.802491 	auc_val: 0.792648 	f1_train: 0.809576 	f1_val: 0.382732
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_smoteTomek20_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.685151 	auc_val: 0.683091 	f1_train: 0.513389 	f1_val: 0.465528
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_smoteTomek50_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.804679 	auc_val: 0.795076 	f1_train: 0.811269 	f1_val: 0.384286
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_train.csv
# ----------------------------------------------------------------------
# auc_train: 0.628154 	auc_val: 0.635623 	f1_train: 0.396192 	f1_val: 0.415459
# ----------------------------------------------------------------------
# {'C': 1000, 'penalty': 'l2', 'random_state': 2020, 'solver': 'saga'}
# preprocess_v2_under50_train.csv
# ----------------------------------------------------------------------
# 100%|██████████| 28/28 [17:51<00:00, 38.25s/it]
# auc_train: 0.787761 	auc_val: 0.800623 	f1_train: 0.795087 	f1_val: 0.383690

# %%
df_results
# Out:
#                 preproc_label       model_label método  \
# 0        preprocess_v1_over50  xgboost_baseline    fit
# 1       preprocess_v1_smote20  xgboost_baseline    fit
# 2       preprocess_v1_smote50  xgboost_baseline    fit
# 3  preprocess_v1_smoteTomek20  xgboost_baseline    fit
# 4  preprocess_v1_smoteTomek50  xgboost_baseline    fit
#
#                                           parámetros columnas_out  auc_train  \
# 0  {'C': 0.001, 'penalty': 'l1', 'random_state': ...                0.772961
# 1  {'C': 0.001, 'penalty': 'l1', 'random_state': ...                0.543655
# 2  {'C': 0.001, 'penalty': 'l1', 'random_state': ...                0.788791
# 3  {'C': 0.001, 'penalty': 'l1', 'random_state': ...                0.540606
# 4  {'C': 0.001, 'penalty': 'l1', 'random_state': ...                0.792838
#
#     auc_val threshold  f1_train    f1_val
# 0  0.779456         1  0.784061  0.346537
# 1  0.551785         0  0.285704  0.157028
# 2  0.781288         1  0.802107  0.348910
# 3  0.548873         0  0.267336  0.157028
# 4  0.782408         1  0.805856  0.349722

# %%
MODELS = DATA/'models'

# %%
df_results.to_csv(f'{MODELS}/logistic_base_MIN_IV.csv', index = False)

# %%
df_results.to_csv('logistic_base_MIN_IV.csv')

# %%
df_results.to_excel(f'{MODELS}/logistic_base_MIN_IV.xlsx', index = False)
